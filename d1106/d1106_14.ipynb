# %%
# 제목
# 관객수 : 숫자입력
# 1,312 -> 1312
# 날짜

# %%
import pandas as pd
data = pd.read_csv("C:/workspace/smclass/d1106/movielist.csv",encoding='utf8')
df = pd.DataFrame(data)
# Out:
#                              제목       관객수         개봉일
# 0                         서울의 봄  13120000  2023.11.22
# 1                         범죄도시3  10680000  2023.05.31
# 2                          엘리멘탈   7240000  2023.06.14
# 3                      스즈메의 문단속   5570000  2024.01.10
# 4                            밀수   5140000  2023.07.26
# 5                    더 퍼스트 슬램덩크   4880000  2023.01.04
# 6         가디언즈 오브 갤럭시: Volume 3   4200000  2023.05.03
# 7      미션 임파서블: 데드 레코닝 PART ONE   4020000  2023.07.12
# 8                     콘크리트 유토피아   3840000  2023.08.09
# 9                     아바타: 물의 길  10800000  2022.12.14
# 10                        범죄도시2  12690000  2022.05.18
# 11                      탑건: 매버릭   8230000  2022.06.22
# 12                    아바타: 물의 길  10800000  2022.12.14
# 13                    한산: 용의 출현   7260000  2022.07.27
# 14                   공조2: 인터내셔날   6980000  2022.09.07
# 15          닥터 스트레인지: 대혼돈의 멀티버스   5880000  2022.05.04
# ...
